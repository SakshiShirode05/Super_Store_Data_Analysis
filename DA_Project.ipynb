# %%
import numpy as np
import pandas as pd

# %%
#data from schema file 
customers_list = ['custno','firstname','lastname','gender','age','profession','contactNo',
'emailId','city','state','isActive','createdDate','UpdatedDate']

products_list = ['productno','productName','Description','isActive','createdDate','UpdatedDate']

transactions_list = ['txnno','txndate','custno','amount','productno','spendby']

# %%
#file upload
# header->(header=none) not mandatory 0r (names=column name)
df_cust = pd.read_csv("C:\\Users\\saksh\\Downloads\\CSV_s1-20230203T090516Z-001\\CSV_s1\\customers.csv",names=customers_list)
df_prod = pd.read_csv("C:\\Users\\saksh\\Downloads\\CSV_s1-20230203T090516Z-001\\CSV_s1\\products.csv",names=products_list)
df_trans = pd.read_csv("C:\\Users\\saksh\\Downloads\\CSV_s1-20230203T090516Z-001\\CSV_s1\\transactions.csv",names=transactions_list)

# %%
df_cust
# Out:
#      custno firstname  lastname gender  age profession  contactNo  \
# 0         1    Leslie      Bass      F   27          B      37307
# 1         2      Judy     Burks      M   53          S      84759
# 2         3    Marsha     Doyle      F   48          B      80932
# 3         4    Alexis    Battle      M   27          S      71701
# 4         5    Martha     Combs      F   49          B      83947
# ..      ...       ...       ...    ...  ...        ...        ...
# 995     964     Jared  McDowell      M   57          S      81891
# 996     965      Rita    Bender      F   46          B      57356
# 997     966     Myron     Blake      M   46          S      82675
# 998     967      Tina   Sargent      F   60          B      32097
# 999     968     Paula     Young      M   32          S      23603
#
#                           emailId        city        state isActive  \
# 0          endslost@everyma1l.org      Gibson     Dellwood        Y
# ...

# %%
df_prod
# Out:
#      productno  productName Description isActive          createdDate  \
# 0            1     Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1            2     Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2            3     Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3            4     Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4            5     Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
# ..         ...          ...         ...      ...                  ...
# 995        996   Product996  acvxzpvhyu        Y  2017-09-09 07:49:14
# 996        997   Product997  eguyggimfm        Y  2017-09-14 12:13:29
# 997        998   Product998  hagbslxugf        Y  2017-04-20 06:25:03
# 998        999   Product999  iuoraxdrlf        Y  2017-03-06 05:00:08
# 999       1000  Product1000  ewgaacrkht        N  2017-07-13 02:52:44
#
#              UpdatedDate
# 0    2017-10-18 12:12:38
# 1    2017-10-18 12:12:38
# 2    2017-10-18 12:12:38
# ...

# %%
df_trans
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 0        1  2017-10-18 12:31:45     923    2559        376    Card
# 1        2  2017-10-18 12:31:45     219    1706        151    Card
# 2        3  2017-10-18 12:31:45     927    3462        707    Cash
# 3        4  2017-10-18 12:31:45     806     865        539    Card
# 4        5  2017-10-18 12:31:45     958    2494         25    Card
# ..     ...                  ...     ...     ...        ...     ...
# 995    996  2017-10-18 12:31:46     653    2872        155    Cash
# 996    997  2017-10-18 12:31:46     849     815        386    Card
# 997    998  2017-10-18 12:31:46     939    3932        529    Card
# 998    999  2017-10-18 12:31:46     547    3021        774    Cash
# 999   1000  2017-10-18 12:31:46     204    2314        828    Card
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Usecase-1 Load all three csv datasets in Pandas Data frames and display first 5 records.

# %%
df_cust.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# ...

# %%
df_prod.head()
# Out:
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
df_trans.head()
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %% [markdown]
# # Usecase-2 Display only those customers from CSV_s1, who purchased more than 3 products

# %%
#groupby on 'custno'
#aggrecation function -count
#transaction = all details hence groupby on df_trans
dfcust = df_trans[df_trans.groupby('custno')['productno'].transform(lambda x:x.count()>3)]

# %%
dfcust
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 15      16  2017-10-18 12:31:45     326    4005        133    Card
# 20      21  2017-10-18 12:31:45     167     509        583    Cash
# 24      25  2017-10-18 12:31:45     753    1796        471    Card
# 37      38  2017-10-18 12:31:45     828    4919        262    Card
# 43      44  2017-10-18 12:31:45       4    3754        773    Card
# ..     ...                  ...     ...     ...        ...     ...
# 926    927  2017-10-18 12:31:46     578    3675        564    Cash
# 950    951  2017-10-18 12:31:46     537    4056        420    Cash
# 962    963  2017-10-18 12:31:46     321    2745        463    Cash
# 987    988  2017-10-18 12:31:46     391    1273        193    Card
# 989    990  2017-10-18 12:31:46       4    1892        548    Cash
#
# [78 rows x 6 columns]

# %%
dfcust = df_trans[df_trans.groupby('custno')['productno'].transform(lambda x:x.count()>3)]['custno'].unique()

# %%
dfcust
# Out:
# array([326, 167, 753, 828,   4, 578, 558, 237,  86, 537, 187, 241, 331,
#        735, 391, 356, 321, 709, 989], dtype=int64)

# %%
dfcust.to_csv("D:\\Da_Project\\project\\Customers who purchase more than 3 products.csv")

# %% [markdown]
# # Usecase-3 Display top 5 most demanded products from CSV_s1

# %%
# product related display details hence groupby on productno
df1 = df_trans.groupby('productno').count().sort_values('txnno',ascending=False).head()

# %%
df1
# Out:
#            txnno  txndate  custno  amount  spendby
# productno
# 82             5        5       5       5        5
# 768            5        5       5       5        5
# 900            5        5       5       5        5
# 427            5        5       5       5        5
# 233            4        4       4       4        4

# %%
df1 =df_trans['productno'].value_counts().head()

# %%
df1
# Out:
# 82     5
# 427    5
# 900    5
# 768    5
# 849    4
# Name: productno, dtype: int64

# %%
df1.to_csv("D:\\Da_Project\\project\\Display top 5 most demanded products.csv ")

# %% [markdown]
# # Usecase-4 Display top 5 transactions amount from CSV_s1

# %%
#4 function use
df2 =df_trans.groupby('amount').max().sort_values('amount',ascending=False).head()

# %%
df2
# Out:
#         txnno              txndate  custno  productno spendby
# amount
# 4996      557  2017-10-18 12:31:46     670        509    Card
# 4992      306  2017-10-18 12:31:46     448        427    Cash
# 4981      575  2017-10-18 12:31:46     305        549    Card
# 4980      532  2017-10-18 12:31:46     230        658    Card
# 4966      233  2017-10-18 12:31:45     287        685    Card

# %%
# 2 function use 
df1 =df_trans.sort_values("amount",ascending=False).head()

# %%
df1
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 556    557  2017-10-18 12:31:46     670    4996        509    Card
# 305    306  2017-10-18 12:31:46     448    4992        427    Cash
# 574    575  2017-10-18 12:31:46     305    4981        549    Card
# 531    532  2017-10-18 12:31:46     230    4980        658    Card
# 232    233  2017-10-18 12:31:45     287    4966        685    Card

# %%
df2.to_csv("D:\\Da_Project\\project\\Display top 5 transactions amount.csv ")

# %% [markdown]
# # Usecase-5 Display distinct professions from CSV_s1

# %%
df3 = df_cust['profession'].unique()

# %%
df3
# Out:
# array(['B', 'S'], dtype=object)

# %%
df3.to_csv("D:\\Da_Project\\project\\Display distinct professions.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5464\1129818487.py in <module>
# ----> 1 df3.to_csv("D:\\Da_Project\\project\\Display distinct professions.csv")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %% [markdown]
# # Usecase-6 Display highest age in CSV_s1 customer’s dataset

# %%
df4 = df_cust['age'].max()

# %%
df4
# Out:
# 64

# %% [markdown]
# # Usecase-7  Display custno, gender, age, profession, contactno, productno, productName, txndate, spendby, amount from CSV_s1 for custno = 923

# %%
c = pd.concat([df_cust,df_prod,df_trans],axis=1)
print(c.loc[922],['custno', 'gender', 'age', 'profession', 'contactno', 'productno', 'productName', 'txndate', 'spendby', 'amount'])
# Out:
# custno                         923
# firstname                  Russell
# lastname                   Walters
# gender                           F
# age                             46
# profession                       B
# contactNo                    25436
# emailId        esears55@ma1lbox.us
# city                      Cuthbert
# state                        Odell
# isActive                         Y
# createdDate    2017-07-30 01:30:09
# UpdatedDate    2017-10-18 12:12:29
# productno                      923
# productName             Product923
# Description             pmogmtllcd
# isActive                         Y
# createdDate    2017-04-03 04:34:07
# UpdatedDate    2017-10-18 12:12:39
# txnno                          923
# txndate        2017-10-18 12:31:46
# custno                         847
# amount                        1948
# productno                      672
# spendby                       Card
# ...

# %%
c =df_trans[df_trans['custno']==923]
c
# Out:
#      txnno              txndate  custno  amount  productno spendby
# 0        1  2017-10-18 12:31:45     923    2559        376    Card
# 334    335  2017-10-18 12:31:46     923    2303        113    Card
# 932    933  2017-10-18 12:31:46     923    4553        644    Cash

# %%
c = pd.m

# %%
c.to_csv('D:\\Da_Project\\project\\custn0 23 all records.csv')

# %% [markdown]
# # Usecase-8 Load all three PSV (pipe separated values) dataset in Pandas Data frames and display first 5 records.

# %%
import pandas as pd

# %%
customers_list = ['custno','firstname','lastname','gender','age','profession','contactNo','emailId','city','state','isActive'
                  ,'createData','UpdateDate']
product_list =['productno','productName','Descripion','isActive','createDate','UpdateDate']
                  
transaction_list =['txnno','txndate','custono','amount','roductno','spendby']

# %%
df_psvC = pd.read_csv("C:\\Users\\saksh\\Downloads\\PSV_s2-20230203T091019Z-001\\PSV_s2\\customers.txt",delimiter='|'
                      ,names=customers_list)
df_psvP = pd.read_csv("C:\\Users\\saksh\\Downloads\\PSV_s2-20230203T091019Z-001\\PSV_s2\\products.txt",delimiter= '|'
                      ,names=products_list)
df_psvT = pd.read_csv("C:\\Users\\saksh\\Downloads\\PSV_s2-20230203T091019Z-001\\PSV_s2\\transactions.txt",delimiter='|'
                      ,names=transactions_list)

# %%
df_psvC.head()
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive           createData  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#             UpdateDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# ...

# %% [markdown]
# # Usecase-9 Load all three JSON datasets in Pandas Data frames and display first 5 records.

# %%
df_jsonC = pd.read_json("C:\\Users\\saksh\\Downloads\\JSON_s3-20230203T090533Z-001\\JSON_s3\\customers.json",lines=True)
df_jsonP = pd.read_json("C:\\Users\\saksh\\Downloads\\JSON_s3-20230203T090533Z-001\\JSON_s3\\products.json",lines=True)
df_jsonT = pd.read_json("C:\\Users\\saksh\\Downloads\\JSON_s3-20230203T090533Z-001\\JSON_s3\\transactions.json",lines=True)

# %%
df_jsonC.head()
# Out:
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# 0  2017-03-01  2018-08-25
# ...

# %% [markdown]
# # Usecase-10  Load all three XML datasets in Pandas Data frames and display first 5 records.

# %%
df_xmlC = pd.read_xml("C:\\Users\\saksh\\Downloads\\XML_s4-20230203T091034Z-001\\XML_s4\\customers.xml")
df_xmlP = pd.read_xml("C:\\Users\\saksh\\Downloads\\XML_s4-20230203T091034Z-001\\XML_s4\\products.xml")
df_xmlT = pd.read_xml("C:\\Users\\saksh\\Downloads\\XML_s4-20230203T091034Z-001\\XML_s4\\transactions.xml")

# %%
df_xmlC.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# ...
